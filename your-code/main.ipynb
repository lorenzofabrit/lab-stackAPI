# %% [markdown]
# # StackAPI
#
# #### Import the necessary libraries here:

# %%
# your code here
import requests 
import pandas as pd
from stackapi import StackAPI
import json

# %%
SITE = StackAPI('stackoverflow')
comments = SITE.fetch('comments')
comments
# Out:
# {'backoff': 0,
#  'has_more': True,
#  'page': 5,
#  'quota_max': 300,
#  'quota_remaining': 300,
#  'total': 0,
#  'items': [{'owner': {'reputation': 503,
#     'user_id': 3527843,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/DWtpE.jpg?s=128&g=1',
#     'display_name': 'Muhammad Ali',
#     'link': 'https://stackoverflow.com/users/3527843/muhammad-ali'},
#    'reply_to_user': {'reputation': 59,
#     'user_id': 11256580,
#     'user_type': 'registered',
#     'profile_image': 'https://lh5.googleusercontent.com/-ZL2342iRoKg/AAAAAAAAAAI/AAAAAAAAAAA/ACHi3rdOsJJtkMcvoHuQ1-NkJ3Hhh7Bs-Q/mo/photo.jpg?sz=128',
#     'display_name': 'larry_82',
#     'link': 'https://stackoverflow.com/users/11256580/larry-82'},
#    'edited': False,
#    'score': 0,
#    'creation_date': 1580405068,
#    'post_id': 59990496,
#    'comment_id': 106095836},
#   {'owner': {'reputation': 23,
#     'user_id': 12647428,
#     'user_type': 'registered',
# ...

# %% [markdown]
# #### Question 1: Find the questions and answers of last month.

# %%
# your code here
questions = SITE.fetch('questions', fromdate=1577721286, todate=1580400363)
questions
# Out:
# {'backoff': 0,
#  'has_more': True,
#  'page': 5,
#  'quota_max': 300,
#  'quota_remaining': 300,
#  'total': 0,
#  'items': [{'tags': ['sas', 'mean', 'proc'],
#    'owner': {'reputation': 2246,
#     'user_id': 3507584,
#     'user_type': 'registered',
#     'accept_rate': 97,
#     'profile_image': 'https://www.gravatar.com/avatar/4566e93d939844b0ee480c2a23e29aab?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'user3507584',
#     'link': 'https://stackoverflow.com/users/3507584/user3507584'},
#    'is_answered': True,
#    'view_count': 17,
#    'accepted_answer_id': 59983888,
#    'answer_count': 2,
#    'score': 0,
#    'last_activity_date': 1580405082,
#    'creation_date': 1580377577,
#    'question_id': 59983088,
#    'link': 'https://stackoverflow.com/questions/59983088/proc-means-save-table-shown-in-results-and-not-in-output-data',
#    'title': 'PROC MEANS - Save table shown in results and not in Output Data'},
#   {'tags': ['qt-designer', 'pyside2'],
# ...

# %%
questions['items'][92]['title']
# Out:
# 'Write values to XLS file with Python'

# %%
print(json.dumps(questions, indent=4))
# Out:
# {
#     "backoff": 0,
#     "has_more": true,
#     "page": 5,
#     "quota_max": 300,
#     "quota_remaining": 300,
#     "total": 0,
#     "items": [
#         {
#             "tags": [
#                 "sas",
#                 "mean",
#                 "proc"
#             ],
#             "owner": {
#                 "reputation": 2246,
#                 "user_id": 3507584,
#                 "user_type": "registered",
#                 "accept_rate": 97,
#                 "profile_image": "https://www.gravatar.com/avatar/4566e93d939844b0ee480c2a23e29aab?s=128&d=identicon&r=PG&f=1",
#                 "display_name": "user3507584",
#                 "link": "https://stackoverflow.com/users/3507584/user3507584"
#             },
#             "is_answered": true,
#             "view_count": 17,
#             "accepted_answer_id": 59983888,
#             "answer_count": 2,
#             "score": 0,
#             "last_activity_date": 1580405082,
# ...

# %%
df = pd.DataFrame(questions)
df
# Out:
#      backoff  has_more  page  quota_max  quota_remaining  total  \
# 0          0      True     5        300              300      0
# 1          0      True     5        300              300      0
# 2          0      True     5        300              300      0
# 3          0      True     5        300              300      0
# 4          0      True     5        300              300      0
# ..       ...       ...   ...        ...              ...    ...
# 495        0      True     5        300              300      0
# 496        0      True     5        300              300      0
# 497        0      True     5        300              300      0
# 498        0      True     5        300              300      0
# 499        0      True     5        300              300      0
#
#                                                  items
# 0    {'tags': ['sas', 'mean', 'proc'], 'owner': {'r...
# 1    {'tags': ['qt-designer', 'pyside2'], 'owner': ...
# ...

# %%
mylist = []

for i in range(92):
    mylist.append(questions['items'][i]['title'])
    
mylist
# Out:
# ['PROC MEANS - Save table shown in results and not in Output Data',
#  'Is it possible to set widget position fixed in qt-desiger',
#  'Haskell computationally intensive thread blocks all other threads',
#  'How to parse output from owping?',
#  'Concatenate CSVs into XLSX files based on filename (pandas)',
#  'How to save python pptx on colab',
#  'vb.net merge multiple filesysteminfo into one filesysteminfo',
#  'How to make an &quot;Undefined property&quot; error a fatal error and kill the script?',
#  'detect form change with excpetion of checkbox',
#  'How to recognize a JSON format in APP Service',
#  'Rewrite rule works in tester but not in .htaccess',
#  'How to delete a complete row on button click in javascript?',
#  'PM2 log: Launching in no daemon mode',
#  'Destination only works when Lambda is invoked through AWS CLI',
#  'How to detect if coordinate is inside region?',
#  'What is the best way to implement client-side paginated API calls with Vertx?',
# ...

# %% [markdown]
# #### Question 2: Find the most voted question today with at least a score of 5 and tagged with 'python'.

# %%
# your code here
questionsmostvoted = SITE.fetch('questions', fromdate=1577664000, todate=1580403092,
min=5, tagged='python', sort='votes')
questions
# Out:
# {'backoff': 0,
#  'has_more': True,
#  'page': 5,
#  'quota_max': 300,
#  'quota_remaining': 300,
#  'total': 0,
#  'items': [{'tags': ['sas', 'mean', 'proc'],
#    'owner': {'reputation': 2246,
#     'user_id': 3507584,
#     'user_type': 'registered',
#     'accept_rate': 97,
#     'profile_image': 'https://www.gravatar.com/avatar/4566e93d939844b0ee480c2a23e29aab?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'user3507584',
#     'link': 'https://stackoverflow.com/users/3507584/user3507584'},
#    'is_answered': True,
#    'view_count': 17,
#    'accepted_answer_id': 59983888,
#    'answer_count': 2,
#    'score': 0,
#    'last_activity_date': 1580405082,
#    'creation_date': 1580377577,
#    'question_id': 59983088,
#    'link': 'https://stackoverflow.com/questions/59983088/proc-means-save-table-shown-in-results-and-not-in-output-data',
#    'title': 'PROC MEANS - Save table shown in results and not in Output Data'},
#   {'tags': ['qt-designer', 'pyside2'],
# ...

# %% [markdown]
# #### Question 3: Find the answers with id 6784 and 6473.

# %%
questions['items'][0]['accepted_answer_id']
# Out:
# 59983888

# %%
answerid = SITE.fetch('answers', ids=[6784, 6473])
answerid
# Out:
# {'backoff': 0,
#  'has_more': False,
#  'page': 1,
#  'quota_max': 300,
#  'quota_remaining': 300,
#  'total': 0,
#  'items': [{'owner': {'reputation': 28529,
#     'user_id': 758,
#     'user_type': 'registered',
#     'accept_rate': 77,
#     'profile_image': 'https://www.gravatar.com/avatar/0b4adc19284ed0751844d610555dc6b2?s=128&d=identicon&r=PG',
#     'display_name': 'Mark Renouf',
#     'link': 'https://stackoverflow.com/users/758/mark-renouf'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1218291583,
#    'creation_date': 1218291583,
#    'answer_id': 6784,
#    'question_id': 6778}]}
